# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\verus\anaconda3\lib\site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\verus\anaconda3\lib\site-packages (from sqlalchemy) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\verus\anaconda3\lib\site-packages (from sqlalchemy) (2.0.1)

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\verus\anaconda3\lib\site-packages (1.1.0)

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np
import matplotlib.pyplot as plt
sustainable = pd.read_csv(r'C:\Users\verus\OneDrive\Documents\GitHub\IronHack\global_energy_project\sustainable.csv')

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
bd = "sustainability"
connection_string = 'mysql+pymysql://root:' + password + '@localhost/'+bd
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sustainability)

# %%
sustainable.to_sql('sustainable',con=engine.connect(),if_exists='replace',index=False)
sustainable
# Out:
#            Entity  Year  Access_to_electricity_(%_of_population)  \
# 0     Afghanistan  2000                                      2.0
# 1     Afghanistan  2001                                      4.0
# 2     Afghanistan  2002                                      9.0
# 3     Afghanistan  2003                                     15.0
# 4     Afghanistan  2004                                     20.0
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                     43.0
# 3645     Zimbabwe  2017                                     44.0
# 3646     Zimbabwe  2018                                     46.0
# 3647     Zimbabwe  2019                                     47.0
# 3648     Zimbabwe  2020                                     53.0
#
#       Access_to_clean_fuels_for_cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# 3                                   9.5
# 4                                  10.9
# ...                                 ...
# 3644                               29.8
# 3645                               29.8
# 3646                               29.9
# 3647                               30.1
# 3648                               30.4
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 0                                                  9.22
# 1                                                  8.86
# 2                                                  8.47
# 3                                                  8.09
# 4                                                  7.75
# ...                                                 ...
# 3644                                              62.88
# 3645                                              62.33
# 3646                                              82.53
# 3647                                              81.40
# 3648                                              80.61
#
#       Financial_flows_to_developing_countries_(US_$)  \
# 0                                            20000.0
# 1                                           130000.0
# 2                                          3950000.0
# 3                                         25970000.0
# 4                                                NaN
# ...                                              ...
# 3644                                         30000.0
# 3645                                       5570000.0
# 3646                                         10000.0
# 3647                                        250000.0
# 3648                                         30000.0
#
#       Renewable_energy_share_in_the_total_final_energy_consumption_(%)  \
# 0                                                 44.99
# 1                                                 45.60
# 2                                                 37.83
# 3                                                 36.66
# 4                                                 44.24
# ...                                                 ...
# 3644                                              81.90
# 3645                                              82.46
# 3646                                              80.23
# 3647                                              81.50
# 3648                                              81.90
#
#       Electricity_from_fossil_fuels_(TWh)  Electricity_from_nuclear_(TWh)  \
# 0                                    0.16                             0.0
# 1                                    0.09                             0.0
# 2                                    0.13                             0.0
# 3                                    0.31                             0.0
# 4                                    0.33                             0.0
# ...                                   ...                             ...
# 3644                                 3.50                             0.0
# 3645                                 3.05                             0.0
# 3646                                 3.73                             0.0
# 3647                                 3.66                             0.0
# 3648                                 3.40                             0.0
#
#       Electricity_from_renewables_(TWh)  ...  \
# 0                                  0.31  ...
# 1                                  0.50  ...
# 2                                  0.56  ...
# 3                                  0.63  ...
# 4                                  0.56  ...
# ...                                 ...  ...
# 3644                               3.32  ...
# 3645                               4.30  ...
# 3646                               5.46  ...
# 3647                               4.58  ...
# 3648                               4.19  ...
#
#       Primary_energy_consumption_per_capita_(kWh/person)  \
# 0                                             302.59482
# 1                                             236.89185
# 2                                             210.86215
# 3                                             229.96822
# 4                                             204.23125
# ...                                                 ...
# 3644                                         3227.68020
# 3645                                         3068.01150
# 3646                                         3441.98580
# 3647                                         3003.65530
# 3648                                         2680.13180
#
#       Energy_intensity_level_of_primary_energy_(MJ/$2017_PPP_GDP)  \
# 0                                                  1.64
# 1                                                  1.74
# 2                                                  1.40
# 3                                                  1.40
# 4                                                  1.20
# ...                                                 ...
# 3644                                              10.00
# 3645                                               9.51
# 3646                                               9.83
# 3647                                              10.47
# 3648                                              10.00
#
#       Value_co2_emissions_kt_by_country  \
# 0                            760.000000
# 1                            730.000000
# 2                           1029.999971
# 3                           1220.000029
# 4                           1029.999971
# ...                                 ...
# 3644                       11020.000460
# 3645                       10340.000150
# 3646                       12380.000110
# 3647                       11760.000230
# 3648                                NaN
#
#       Renewables_(%_equivalent_primary_energy)  gdp_growth  gdp_per_capita  \
# 0                                          NaN         NaN             NaN
# 1                                          NaN         NaN             NaN
# 2                                          NaN         NaN      179.426579
# 3                                          NaN    8.832278      190.683814
# 4                                          NaN    1.414118      211.382074
# ...                                        ...         ...             ...
# 3644                                       NaN    0.755869     1464.588957
# 3645                                       NaN    4.709492     1235.189032
# 3646                                       NaN    4.824211     1254.642265
# 3647                                       NaN   -6.144236     1316.740657
# 3648                                       NaN   -6.248748     1214.509820
#
#       Density  Land_Area(Km2)   Latitude  Longitude
# 0        60.0        652230.0  33.939110  67.709953
# 1        60.0        652230.0  33.939110  67.709953
# 2        60.0        652230.0  33.939110  67.709953
# 3        60.0        652230.0  33.939110  67.709953
# 4        60.0        652230.0  33.939110  67.709953
# ...       ...             ...        ...        ...
# 3644     38.0        390757.0 -19.015438  29.154857
# 3645     38.0        390757.0 -19.015438  29.154857
# 3646     38.0        390757.0 -19.015438  29.154857
# 3647     38.0        390757.0 -19.015438  29.154857
# 3648     38.0        390757.0 -19.015438  29.154857
#
# [3649 rows x 21 columns]
